# %%
# Reference 
# 50 -> 2400 images of 256 x 256 pixels 
# image augumentation 90, 180, 270
# A total of 12,000 SEM Image

# %% [markdown]
# # OpenCV Python

# %%
import cv2
from PIL import Image
import matplotlib.pyplot as plt

# %% [markdown]
# ### 1. Image Size Check

# %%
image = cv2.imread('images/40-1-1.tif')
height, width, channels = image.shape

print(f'이미지 크기: 높이 {height}, 너비 {width}, 채널 {channels}')
# 이미지 크기: 높이 1088, 너비 1636, 채널 3
# Out:
# 이미지 크기: 높이 1088, 너비 1636, 채널 3

# %%
# # 이미지를 RGB로 변환 (OpenCV는 BGR을 사용하므로 RGB로 변환해야 함)
# image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# # 이미지 표시
# display(Image(data=image_rgb))

# %%
image = Image.open('images/40-1-1.tif').convert('RGB')

# PNG로 저장
png_image_path = 'converted_image.png'
image.save(png_image_path)

# %%
plt.imshow(image)
plt.axis('off')  # 축 숨김
plt.show()

# %% [markdown]
# ### 2. Image Rotation

# %% [markdown]
# ### 3. Image

# %%
png_image_path = 'converted_image.png'
cv2.imwrite(png_image_path, image, [cv2.IMWRITE_PNG_COMPRESSION, 0]) 
image = Image.open(tiff_image_path)

# 이미지 표시
plt.imshow(image)
